# %% [markdown]
# <a href="https://colab.research.google.com/github/megatron3002/Bioinformatics/blob/main/notebooks/Bioinformatics_Module03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem 1: Variables and Some Arithmetic

# %%
a,b= 986, 984
c=(a**2)+(b**2)
print(c)
# Out:
# 1940452

# %% [markdown]
# #Problem 2: Strings and Lists

# %%
s="AtrZeF0ME9HXb3BFK1Fmg3sClZREmr5qfnuXmqawc7hfwtJGdu8PEn3lCFkDZrPr0M1jRNwm2PBronchocelaiFFuEs5r0gmFjcPvastusw9xylJrRVwioUEbFbwd8gXfBUnp9c8zA9hCtcsrfIOLo2CoyrgjZW4N9mh6HhZjitrnnuM5HbcwXNKYL."
a,b,c,d = 74, 84, 100, 105
print(s[a:b+1],s[c:d+1])
# Out:
# Bronchocela vastus

# %% [markdown]
# # Problem 3: Conditions and Loops

# %%
a,b,sum = 4477,8848,0
for i in range(a, b + 1):
  if i % 2 == 1:
    sum += i
print(sum)
# Out:
# 14563132

# %% [markdown]
# #Problem 4: Working with Files

# %%
from google.colab import files
uploaded = files.upload()

with open('rosalind_ini5.txt', 'r') as file:
        lines = file.readlines()
print('\n')
for line in lines[1::2]:
        print(line.strip('\n'))
# Out:
#      <input type="file" id="files-e9fd3619-e762-4f39-a7d1-a5faa85e426e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9fd3619-e762-4f39-a7d1-a5faa85e426e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Problem 5:
